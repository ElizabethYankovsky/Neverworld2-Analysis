# %%
# %reset
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import cartopy.crs as ccrs
import netCDF4 as nc
import matplotlib.ticker as mticker
import warnings; warnings.filterwarnings('ignore')
import cmocean
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
# %cd /glade/p/univ/unyu0004/neerajab/NeverWorld2/

run=20 #1/4 degree NeverWorld setup
fs1=xr.open_dataset('run%i/static.nc' % (run), decode_times=False)
os1=xr.open_dataset('run%i/ocean.stats.nc' % (run), decode_times=False)
tau = 500*86400
end_time = 30500
start_time = end_time - tau/86400

av1     = xr.open_dataset('run%i/averages_000%i.nc' % (run, end_time-500+2), decode_times=False)  #5-day average
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/
# Out:
# /glade/p/univ/unyu0004/neerajab/NeverWorld2
# /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis

# %%
# %cd /glade/p/univ/unyu0004/neerajab/NeverWorld2/

run=26 #1/8 degree NeverWorld setup
fs2=xr.open_dataset('run%i/static.nc' % (run), decode_times=False)
os2=xr.open_dataset('run%i/ocean.stats.nc' % (run), decode_times=False)
tau = 500*86400
end_time = 30500
start_time = end_time - tau/86400

av2     = xr.open_dataset('run%i/averages_000%i.nc' % (run, end_time-500+2), decode_times=False)  #5-day average
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/
# Out:
# /glade/p/univ/unyu0004/neerajab/NeverWorld2
# /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis

# %%
#Print the average file information: 
#av1
#Print the static file information: fs1
#Print ocean stats file: 

os1
# Out:
# <xarray.Dataset>
# Dimensions:        (Interface: 16, Layer: 15, Time: 6680)
# Coordinates:
#   * Layer          (Layer) float64 1.023e+03 1.023e+03 ... 1.028e+03 1.028e+03
#   * Interface      (Interface) float64 1.022e+03 1.023e+03 ... 1.028e+03
#   * Time           (Time) float64 0.0 5.0 10.0 ... 3.049e+04 3.05e+04 3.05e+04
# Data variables:
#     Ntrunc         (Time) float64 ...
#     En             (Time) float64 ...
#     APE            (Time, Interface) float64 ...
#     KE             (Time, Layer) float64 ...
#     H0             (Time, Interface) float64 ...
#     Mass_lay       (Time, Layer) float64 ...
#     Mass           (Time) float64 ...
#     Mass_chg       (Time) float64 ...
#     Mass_anom      (Time) float64 ...
#     max_CFL_trans  (Time) float64 ...
#     max_CFL_lin    (Time) float64 ...
# Attributes:
#     filename:  ./ocean.stats.nc

# %%
#Read in various grid variables from the static file and forcing:

xh1 = fs1.xh.values
yh1 = fs1.yh.values
xq1 = fs1.xq.values
yq1 = fs1.yq.values
APE1= os1.APE.values
Time1=os1.Time.values

xh2 = fs2.xh.values
yh2 = fs2.yh.values
xq2 = fs2.xq.values
yq2 = fs2.yq.values
APE2= os2.APE.values
Time2=os2.Time.values

# %%
EighthRd1.shape
# Out:
# (1120, 480)

# %%
QuarterRd1  = np.nanmean(np.array(av1['Rd1'][:,:,:]),axis=0)#First deformation radius
QuarterRd_dx= np.nanmean(np.array(av1['Rd_dx'][:,:,:]),axis=0) #Ratio Rd1 to dx
EighthRd1   = np.nanmean(np.array(av2['Rd1'][:,:,:]),axis=0) #First deformation radius
EighthRd_dx = np.nanmean(np.array(av2['Rd_dx'][:,:,:]),axis=0) #Ratio Rd1 to dx

# %%
#Plotting Rd_dx 1/4 degree
fig = plt.figure(figsize=(4, 7), dpi=200, facecolor='w', edgecolor='k')
ax1 = fig.add_axes([0.15,0.2,0.6,0.7]) 
ax2 = fig.add_axes([.78, 0.2, 0.03, 0.7])
ax1.set_facecolor((0.92, 0.92, 0.92))
ax1.set_title('Ratio of R$_D$/dx',fontsize=16)
ax1.set_xlabel('Longitude',fontsize=16)
ax1.set_ylabel('Latitude',fontsize=16)
ax1.tick_params(labelsize=16); 
ax2.tick_params(labelsize=14)

levels=np.linspace(0,6,7)
plotted =ax1.contourf(xh1,yh1,QuarterRd_dx,levels=levels,cmap=cmocean.cm.dense,extend='max')
CS=ax1.contour(xh1, yh1,QuarterRd_dx,levels = [2],
                 colors=('r',),linestyles=('-',),linewidths=(2,))
ax1.clabel(CS, fmt = '%2.1d', colors = 'r', fontsize=14)
ax1.set_aspect('equal', 'box')
cbar = plt.colorbar(mappable=plotted, cax=ax2, orientation = 'vertical');
cbar.ax.tick_params(labelsize=14);
#
plt.show()

# %%
#Plotting Rd_dx 1/8 degree
fig = plt.figure(figsize=(4, 7), dpi=200, facecolor='w', edgecolor='k')
ax1 = fig.add_axes([0.15,0.2,0.6,0.7]) 
ax2 = fig.add_axes([.78, 0.2, 0.03, 0.7])
ax1.set_facecolor((0.92, 0.92, 0.92))
ax1.set_title('Ratio of R$_D$/dx',fontsize=16)
ax1.set_xlabel('Longitude',fontsize=16)
ax1.set_ylabel('Latitude',fontsize=16)
ax1.tick_params(labelsize=16); 
ax2.tick_params(labelsize=14)

levels=np.linspace(0,6,7)
plotted =ax1.contourf(xh2,yh2,EighthRd_dx,levels=levels,cmap=cmocean.cm.dense,extend='max')
CS=ax1.contour(xh2, yh2,EighthRd_dx,levels = [2],
                 colors=('r',),linestyles=('-',),linewidths=(2,))
ax1.clabel(CS, fmt = '%2.1d', colors = 'r', fontsize=14)
ax1.set_aspect('equal', 'box')
cbar = plt.colorbar(mappable=plotted, cax=ax2, orientation = 'vertical');
cbar.ax.tick_params(labelsize=14);
#
plt.show()

# %%
#Plotting first deformation radius 1/4 degree
fig = plt.figure(figsize=(4, 7), dpi=200, facecolor='w', edgecolor='k')
ax1 = fig.add_axes([0.15,0.2,0.6,0.7]) 
ax2 = fig.add_axes([.78, 0.2, 0.03, 0.7])
ax1.set_facecolor((0.92, 0.92, 0.92))
ax1.set_title('First deformation radius (km)',fontsize=16)
ax1.set_xlabel('Longitude',fontsize=16)
ax1.set_ylabel('Latitude',fontsize=16)
ax1.tick_params(labelsize=16); 
ax2.tick_params(labelsize=14)

levels=np.linspace(0,150,16)
plotted =ax1.contourf(xh1,yh1,QuarterRd1/1000,levels=levels,cmap=cmocean.cm.deep,extend='max')
ax1.set_aspect('equal', 'box')
cbar = plt.colorbar(mappable=plotted, cax=ax2, orientation = 'vertical');
cbar.ax.tick_params(labelsize=14);
#
plt.show()
#fig.savefig('Rd1.png')

# %%
#Plotting first deformation radius 1/8 degree
fig = plt.figure(figsize=(4, 7), dpi=200, facecolor='w', edgecolor='k')
ax1 = fig.add_axes([0.15,0.2,0.6,0.7]) 
ax2 = fig.add_axes([.78, 0.2, 0.03, 0.7])
ax1.set_facecolor((0.92, 0.92, 0.92))
ax1.set_title('First deformation radius (km)',fontsize=16)
ax1.set_xlabel('Longitude',fontsize=16)
ax1.set_ylabel('Latitude',fontsize=16)
ax1.tick_params(labelsize=16); 
ax2.tick_params(labelsize=14)

levels=np.linspace(0,150,16)
plotted =ax1.contourf(xh2,yh2,EighthRd1/1000,levels=levels,cmap=cmocean.cm.deep,extend='max')
ax1.set_aspect('equal', 'box')
cbar = plt.colorbar(mappable=plotted, cax=ax2, orientation = 'vertical');
cbar.ax.tick_params(labelsize=14);
#
plt.show()
#fig.savefig('Rd1.png')

# %%
#Interpolating the 1/8 degree results onto 1/4 degree grid:
from scipy.interpolate import griddata
X1, Y1 = np.meshgrid(xh1,yh1)
X2, Y2 = np.meshgrid(xh2,yh2)
Int_EighthRd1=griddata((X2.flatten(),Y2.flatten()),EighthRd1.flatten() , (X1,Y1),method='linear')
Int_EighthRd_dx=griddata((X2.flatten(),Y2.flatten()),EighthRd_dx.flatten() , (X1,Y1),method='linear')
np.nanmax(Int_EighthRd1)
# Out:
# 445495.390625

# %%
#Plotting Difference in deformation Radii
fig = plt.figure(figsize=(4, 7), dpi=200, facecolor='w', edgecolor='k')
ax1 = fig.add_axes([0.15,0.2,0.6,0.7]) 
ax2 = fig.add_axes([.78, 0.2, 0.03, 0.7])
ax1.set_facecolor((0.92, 0.92, 0.92))
ax1.set_title('Quarter-Eighth deg. Rd$_1$ (km)',fontsize=14)
ax1.set_xlabel('Longitude',fontsize=16)
ax1.set_ylabel('Latitude',fontsize=16)
ax1.tick_params(labelsize=16); 
ax2.tick_params(labelsize=14)

levels=np.linspace(0,150,16)
plotted =ax1.pcolor(xh1,yh1,(QuarterRd1-Int_EighthRd1)/1000,cmap='RdBu_r',vmin=-2,vmax=2)
ax1.set_aspect('equal', 'box')
cbar = plt.colorbar(mappable=plotted, cax=ax2, orientation = 'vertical');
cbar.ax.tick_params(labelsize=14);
#
plt.show()
#fig.savefig('Rd1.png')

# %%
#Plotting Difference in Rd_dx
fig = plt.figure(figsize=(4, 7), dpi=80, facecolor='w', edgecolor='k')
ax1 = fig.add_axes([0.15,0.2,0.6,0.7]) 
ax2 = fig.add_axes([.78, 0.2, 0.03, 0.7])
ax1.set_facecolor((0.92, 0.92, 0.92))
ax1.set_title('Quarter-Eighth deg. Rd/dx',fontsize=16)
ax1.set_xlabel('Longitude',fontsize=16)
ax1.set_ylabel('Latitude',fontsize=16)
ax1.tick_params(labelsize=16); 
ax2.tick_params(labelsize=14)

levels=np.linspace(0,150,16)
plotted =ax1.pcolor(xh1,yh1,(QuarterRd_dx-Int_EighthRd_dx),cmap='RdBu_r',vmin=-10,vmax=10)
ax1.set_aspect('equal', 'box')
cbar = plt.colorbar(mappable=plotted, cax=ax2, orientation = 'vertical');
cbar.ax.tick_params(labelsize=14);
#
plt.show()
#fig.savefig('Rd1.png')

# %%
fig=plt.figure(figsize=(7, 4), dpi=160, facecolor='w', edgecolor='k')
plt.plot(Time1,np.nansum(APE1,axis=1))
plt.plot(Time2,np.nansum(APE2,axis=1))
plt.plot(Time1,np.nansum(APE1[:,0:8],axis=1))
plt.plot(Time2,np.nansum(APE2[:,0:8],axis=1))
plt.plot(Time1,np.nansum(APE1[:,8:16],axis=1))
plt.plot(Time2,np.nansum(APE2[:,8:16],axis=1))
plt.ylim(0,1.2e20)
plt.legend(['1/4$^\circ$ APE integrated','1/8$^\circ$ APE integrated',
           '1/4$^\circ$ APE highest 8 layers','1/8$^\circ$ highest 8 layers',
           '1/4$^\circ$ APE lowest 8 layers','1/8$^\circ$ lowest 8 layers'])

# %%
Layer1.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-139-b7e123d752c8> in <module>
# ----> 1 Layer1.shape
#
# NameError: name 'Layer1' is not defined
