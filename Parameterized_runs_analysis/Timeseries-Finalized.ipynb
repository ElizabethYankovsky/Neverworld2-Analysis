# %%
from netCDF4 import Dataset
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import xarray as xr
from xgcm import Grid
import numpy as np
import cmocean
import warnings
warnings.filterwarnings("ignore")
print('done')
# Out:
# done

# %%
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/
# %ls
# Out:
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs
# default_noparameterization/       Malte_EBTpower2_0.33deg_tuning1/
# Malte_EBTpower2_0.25deg/          Malte_EBTpower2_0.33deg_tuning2/
# Malte_EBTpower2_0.25deg_tuning1/  Malte_EBTpower2_0.33deg_tuning3/
# Malte_EBTpower2_0.25deg_tuning2/  Malte_EBTpower2_0.33deg_tuning4/
# Malte_EBTpower2_0.25deg_tuning3/  Malte_EBTpower2_0.33deg_tuning5/
# Malte_EBTpower2_0.25deg_tuning4/  Malte_EBTpower2_0.5deg/
# Malte_EBTpower2_0.25deg_tuning5/  Malte_EBTpower2_0.67deg/
# Malte_EBTpower2_0.25deg_tuning6/  Malte_EBTpower2_1deg/
# Malte_EBTpower2_0.25deg_tuning7/  Quarterdeg_sanitycheck/
# Malte_EBTpower2_0.33deg/          Scott_EBTpower4_0.5deg/

# %%
##0.25 degree
##Unparameterized run
# %cd /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.25deg_N15_baseline_hmix5/
fs = xr.open_dataset('static.nc', decode_times=False)
os = xr.open_mfdataset(['sub01/ocean.stats.nc','sub02/ocean.stats.nc'], decode_times=False)

#CBS=-1
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg
fs1 = xr.open_dataset('static.nc', decode_times=False)
os1 = xr.open_dataset('ocean.stats.nc', decode_times=False)

#CBS=-0.8
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg_tuning1
fs2 = xr.open_dataset('static.nc', decode_times=False)
os2 = xr.open_dataset('ocean.stats.nc', decode_times=False)

#CBS=-0.6
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg_tuning2
fs3 = xr.open_dataset('static.nc', decode_times=False)
os3 = xr.open_dataset('ocean.stats.nc', decode_times=False)

#CBS=-0.5
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg_tuning7
fs4 = xr.open_dataset('static.nc', decode_times=False)
os4 = xr.open_dataset('ocean.stats.nc', decode_times=False)

#CBS=-0.4
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg_tuning6
fs5 = xr.open_dataset('static.nc', decode_times=False)
os5 = xr.open_dataset('ocean.stats.nc', decode_times=False)

#CBS=-0.3
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg_tuning5
fs6 = xr.open_dataset('static.nc', decode_times=False)
os6 = xr.open_dataset('ocean.stats.nc', decode_times=False)

#CBS=-0.25
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg_tuning4
fs7 = xr.open_dataset('static.nc', decode_times=False)
os7 = xr.open_dataset('ocean.stats.nc', decode_times=False)

#CBS=-0.1
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg_tuning3
fs8 = xr.open_dataset('static.nc', decode_times=False)
os8 = xr.open_dataset('ocean.stats.nc', decode_times=False)

# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/
# Out:
# /glade/campaign/univ/unyu0004/NeverWorld2/nw2_0.25deg_N15_baseline_hmix5
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg_tuning1
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg_tuning2
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg_tuning7
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg_tuning6
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg_tuning5
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg_tuning4
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.25deg_tuning3
# /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis

# %%
##0.33 degree
# ##Unparameterized run
# %cd /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.25deg_N15_baseline_hmix5/
# fs = xr.open_dataset('static.nc', decode_times=False)
# os = xr.open_mfdataset(['sub01/ocean.stats.nc','sub02/ocean.stats.nc'], decode_times=False)

#CBS=-1
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.33deg
fs1 = xr.open_dataset('static.nc', decode_times=False)
os1 = xr.open_dataset('ocean.stats.nc', decode_times=False)


#CBS=-0.8
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.33deg_tuning5
fs2 = xr.open_dataset('static.nc', decode_times=False)
os2 = xr.open_dataset('ocean.stats.nc', decode_times=False)

#CBS=-0.6
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.33deg_tuning4
fs3 = xr.open_dataset('static.nc', decode_times=False)
os3 = xr.open_dataset('ocean.stats.nc', decode_times=False)

#CBS=-0.5
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.33deg_tuning3
fs4 = xr.open_dataset('static.nc', decode_times=False)
os4 = xr.open_dataset('ocean.stats.nc', decode_times=False)

#CBS=-0.4
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.33deg_tuning2
fs5 = xr.open_dataset('static.nc', decode_times=False)
os5 = xr.open_dataset('ocean.stats.nc', decode_times=False)

#CBS=-0.25
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.33deg_tuning1
fs7 = xr.open_dataset('static.nc', decode_times=False)
os7 = xr.open_dataset('ocean.stats.nc', decode_times=False)



# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/
# Out:
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.33deg
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.33deg_tuning5
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.33deg_tuning4
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.33deg_tuning3
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.33deg_tuning2
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.33deg_tuning1
# /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis

# %%
## 1/2 degree:
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/default_noparameterization
fs = xr.open_dataset('static.nc', decode_times=False)
os = xr.open_dataset('ocean.stats.nc', decode_times=False)

# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_GM_BS_default/
fsGMBS3 = xr.open_dataset('static.nc', decode_times=False)
osGMBS3 = xr.open_dataset('ocean.stats.nc', decode_times=False)

#CBS=-1
# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.5deg
fs1 = xr.open_dataset('static.nc', decode_times=False)
os1 = xr.open_dataset('ocean.stats.nc', decode_times=False)


# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/
# Out:
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/default_noparameterization
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_GM_BS_default
# /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Finalized_Runs/Malte_EBTpower2_0.5deg
# /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis

# %%
plt.figure(figsize=(7,5),dpi=150)



plt.subplot(2,1,1)
#plt.title('1/4 degree runs')

plt.plot(os.Time,os.KE.sum(axis=1),label='Unparameterized',color='tomato'); 
plt.plot(os1.Time,os1.KE.sum(axis=1),label='Parameterized',color='royalblue'); 
#plt.plot(osGMBS3.Time,osGMBS3.KE.sum(axis=1),label='Jansen et al. (2020)',color='gold'); 

plt.plot(os.Time,os.Time*0+1.89e18,'--',label='1/32$^\circ$ coarsened to 1/2 deg.',color='k')


plt.ylabel('KE (Joules)')
plt.grid('on')
# plt.xlim([0,30])
# plt.ylim([.02,.05e18])
plt.xlim([0,30000])
plt.ylim([0,3e18])
#plt.legend()
#plt.title('KE Timeseries')
plt.subplot(2,1,2)


plt.plot(os.Time,os.APE.sum(axis=1),label='Unparameterized',color='tomato'); 
plt.plot(os1.Time,os1.APE.sum(axis=1),label='Parameterized',color='royalblue'); 
#plt.plot(osGMBS3.Time,osGMBS3.APE.sum(axis=1),label='Jansen et al. (2020)',color='gold'); 

plt.plot(os.Time,os.Time*0+9.18e19,'--',label='1/32$^\circ$ coarsened to 1/2 deg.',color='k')


plt.grid('on')
# plt.xlim([0,30])
# plt.ylim([0,.0012e20])
plt.xlim([0,30000])
plt.ylim([0.e20,1.2e20])

#plt.title('APE Timeseries')
plt.ylabel('APE (Joules)')
plt.xlabel('Time (days)')
plt.legend(fontsize=7)
#plt.legend(bbox_to_anchor =(1., 1.),fontsize=7)

# %%
plt.figure(figsize=(7,7),dpi=200)



plt.subplot(2,1,1)
#plt.title('1/4 degree runs')

plt.plot(os.Time,os.KE.sum(axis=1),label='Unparameterized',color='k'); 
plt.plot(os1.Time,os1.KE.sum(axis=1),label='$C_{BS}=-1.0$',color='firebrick'); 
plt.plot(os2.Time,os2.KE.sum(axis=1),label='$C_{BS}=-0.8$',color='red'); 
plt.plot(os3.Time,os3.KE.sum(axis=1),label='$C_{BS}=-0.6$',color='darkorange'); 
plt.plot(os4.Time,os4.KE.sum(axis=1),label='$C_{BS}=-0.5$',color='gold'); 
plt.plot(os5.Time,os5.KE.sum(axis=1),label='$C_{BS}=-0.4$',color='skyblue'); 
plt.plot(os6.Time,os6.KE.sum(axis=1),label='$C_{BS}=-0.3$',color='slateblue'); 
plt.plot(os7.Time,os7.KE.sum(axis=1),label='$C_{BS}=-0.25$',color='darkblue'); 
plt.plot(os8.Time,os8.KE.sum(axis=1),label='$C_{BS}=-0.1$',color='darkmagenta'); 




#plt.plot(os.Time,os.Time*0+1.89e18,'--',label='1/32$^\circ$ coarsened to 1/3 deg.',color='k')
plt.plot(os.Time,os.Time*0+2.22e18,'--',label='1/32$^\circ$ coarsened to 1/4 deg.',color=[0.5,0.5,0.5])


plt.ylabel('KE (Joules)')
plt.grid('on')
# plt.xlim([0,30])
# plt.ylim([.02,.05e18])
plt.xlim([0,30000])
plt.ylim([0,3e18])
#plt.legend()
plt.title('KE Timeseries')
plt.subplot(2,1,2)


plt.plot(os.Time,os.APE.sum(axis=1),label='Unparameterized',color='k'); 
plt.plot(os1.Time,os1.APE.sum(axis=1),label='$C_{BS}=-1.0$',color='firebrick'); 
plt.plot(os2.Time,os2.APE.sum(axis=1),label='$C_{BS}=-0.8$',color='red'); 
plt.plot(os3.Time,os3.APE.sum(axis=1),label='$C_{BS}=-0.6$',color='darkorange'); 
plt.plot(os4.Time,os4.APE.sum(axis=1),label='$C_{BS}=-0.5$',color='gold'); 
plt.plot(os5.Time,os5.APE.sum(axis=1),label='$C_{BS}=-0.4$',color='skyblue'); 
plt.plot(os6.Time,os6.APE.sum(axis=1),label='$C_{BS}=-0.3$',color='slateblue'); 
plt.plot(os7.Time,os7.APE.sum(axis=1),label='$C_{BS}=-0.25$',color='darkblue'); 
plt.plot(os8.Time,os8.APE.sum(axis=1),label='$C_{BS}=-0.1$',color='darkmagenta'); 

plt.plot(os.Time,os.Time*0+9.12e19,'--',label='1/32$^\circ$ coarsened to 1/4 deg.',color=[0.5,0.5,0.5])
#plt.plot(os.Time,os.Time*0+9.18e19,'--',label='1/32$^\circ$ coarsened to 1/2 deg.',color=[0.5,0.5,0.5])


plt.grid('on')
# plt.xlim([0,30])
# plt.ylim([0,.0012e20])
plt.xlim([0,30000])
plt.ylim([0.e20,1.2e20])

plt.title('APE Timeseries')
plt.ylabel('APE (Joules)')
plt.xlabel('Time (days)')
plt.legend(fontsize=7)
#plt.legend(bbox_to_anchor =(1., 1.),fontsize=7)

# %%
ossanity.APE.sum(axis=1)[0:10]
# Out:
# <xarray.DataArray 'APE' (Time: 6)>
# array([1.49808436e+08, 1.47563407e+15, 7.00947316e+15, 1.37158107e+16,
#        2.34706849e+16, 3.48933824e+16])
# Coordinates:
#   * Time     (Time) float64 0.0 5.0 10.0 15.0 20.0 25.0

# %%
os1.APE.sum(axis=1).values[0:7]
# Out:
# array([1.49808436e+08, 1.47563407e+15, 7.00947329e+15, 1.37158198e+16,
#        2.34707925e+16, 3.48935917e+16, 5.13446995e+16])

# %%
osF4.APE.sum(axis=1).values[0:7]
# Out:
# array([1.49808436e+08, 1.47591651e+15, 7.01259276e+15, 1.37857929e+16,
#        2.35599569e+16, 3.49978505e+16, 5.16078560e+16])

# %%
## Scale awareness tests:
##Unparameterized run

# %cd /glade/scratch/eyankovsky/Scale_awareness_tests/MEKE_GM_0.5deg
fsGM3 = xr.open_dataset('static.nc', decode_times=False)
osGM3 = xr.open_dataset('ocean.stats.nc', decode_times=False)

# %cd /glade/scratch/eyankovsky/Scale_awareness_tests/MEKE_BS_0.5deg
fsBS3 = xr.open_dataset('static.nc', decode_times=False)
osBS3 = xr.open_dataset('ocean.stats.nc', decode_times=False)

# %cd /glade/scratch/eyankovsky/Scale_awareness_tests/MEKE_GM_BS_0.5deg
fsGMBS3 = xr.open_dataset('static.nc', decode_times=False)
osGMBS3 = xr.open_dataset('ocean.stats.nc', decode_times=False)

# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Half_degree/05deg_KS01_COEF01
fsScott1 = xr.open_dataset('static.nc', decode_times=False)
osScott1 = xr.open_dataset('ocean.stats.nc', decode_times=False)

# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Half_degree/05deg_KS01_COEF05
fsScott2 = xr.open_dataset('static.nc', decode_times=False)
osScott2 = xr.open_dataset('ocean.stats.nc', decode_times=False)

# %cd /glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Half_degree/05deg_KS01_COEF1
fsScott3 = xr.open_dataset('static.nc', decode_times=False)
osScott3 = xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/
# Out:
# /glade/scratch/eyankovsky/Scale_awareness_tests/MEKE_GM_0.5deg
# /glade/scratch/eyankovsky/Scale_awareness_tests/MEKE_BS_0.5deg
# /glade/scratch/eyankovsky/Scale_awareness_tests/MEKE_GM_BS_0.5deg
# [Errno 2] No such file or directory: '/glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Half_degree/05deg_KS01_COEF01'
# /glade/scratch/eyankovsky/Scale_awareness_tests/MEKE_GM_BS_0.5deg
# [Errno 2] No such file or directory: '/glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Half_degree/05deg_KS01_COEF05'
# /glade/scratch/eyankovsky/Scale_awareness_tests/MEKE_GM_BS_0.5deg
# [Errno 2] No such file or directory: '/glade/scratch/eyankovsky/Backscatter_tests_with_Scott/Half_degree/05deg_KS01_COEF1'
# /glade/scratch/eyankovsky/Scale_awareness_tests/MEKE_GM_BS_0.5deg
# /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis

# %%
plt.figure(figsize=(7,7),dpi=200)



plt.subplot(2,1,1)

plt.plot(osGM3.Time,osGM3.KE.sum(axis=1),label='MEKE+GM 1/2$^\circ$',color='#ADD8E6'); 
plt.plot(osBS3.Time,osBS3.KE.sum(axis=1),label='MEKE+BS 1/2$^\circ$',color='#fe7f2d'); 
plt.plot(osGMBS3.Time,osGMBS3.KE.sum(axis=1),label='MEKE+GM+BS 1/2$^\circ$',color='#fcca46'); 
plt.plot(osGMBS3.Time,osGMBS3.Time*0+1.89e18,label='Coarsened 1/32$^\circ$',color='#619b8a')
plt.plot(osScott1.Time,osScott1.KE.sum(axis=1),label='BOUND_KH_WITH_MEKE_COEF = 0.1; KILL_SWITCH_COEF = 0.1',color='#233d4d')
plt.plot(osScott2.Time,osScott2.KE.sum(axis=1),label='BOUND_KH_WITH_MEKE_COEF = 0.5; KILL_SWITCH_COEF = 0.1',color='b')
plt.plot(osScott3.Time,osScott3.KE.sum(axis=1),label='BOUND_KH_WITH_MEKE_COEF = 1.0; KILL_SWITCH_COEF = 0.1',color='c')

plt.ylabel('KE (Joules)')
plt.grid('on')
plt.xlim([0,35000])
#plt.ylim([0,5e17])
#plt.legend()
plt.title('KE at 1/2 Degree')
plt.subplot(2,1,2)


plt.plot(osGM3.Time,osGM3.APE.sum(axis=1),label='MEKE+GM 1/2$^\circ$',color='#ADD8E6'); 
plt.plot(osBS3.Time,osBS3.APE.sum(axis=1),label='MEKE+BS 1/2$^\circ$',color='#fe7f2d'); 
plt.plot(osGMBS3.Time,osGMBS3.APE.sum(axis=1),label='MEKE+GM+BS 1/2$^\circ$',color='#fcca46'); 
plt.plot(osGMBS3.Time,osGMBS3.Time*0+9.12e19,label='Coarsened 1/32$^\circ$',color='#619b8a')
plt.plot(osScott1.Time,osScott1.APE.sum(axis=1),label='BOUND_KH_WITH_MEKE_COEF = 0.1; KILL_SWITCH_COEF = 0.1',color='#233d4d')
plt.plot(osScott2.Time,osScott2.APE.sum(axis=1),label='BOUND_KH_WITH_MEKE_COEF = 0.5; KILL_SWITCH_COEF = 0.1',color='b')
plt.plot(osScott3.Time,osScott3.APE.sum(axis=1),label='BOUND_KH_WITH_MEKE_COEF = 1.0; KILL_SWITCH_COEF = 0.1',color='c')

plt.grid('on')
plt.xlim([0,35000])
plt.title('APE at 1/2 Degree')
plt.ylabel('APE (Joules)')
plt.xlabel('Time (days)')
plt.legend(loc='lower right',fontsize=8)

# %%
plt.figure(figsize=(7,7),dpi=200)



plt.subplot(2,1,1)

plt.plot(osGM1.Time,osGM1.KE.sum(axis=1),label='MEKE+GM 1/4$^\circ$',color='#233d4d'); 
plt.plot(osGM2.Time,osGM2.KE.sum(axis=1),label='MEKE+GM 1/2$^\circ$',color='#fe7f2d'); 
plt.plot(osGM3.Time,osGM3.KE.sum(axis=1),label='MEKE+GM 1$^\circ$',color='#fcca46'); 
plt.plot(osGM4.Time,osGM4.KE.sum(axis=1),label='MEKE+GM 2$^\circ$',color='#619b8a'); 
#plt.plot(osGM3.Time,osGM3.Time*0+np.nanmean(oshr.KE.sum(axis=1)),label='Truth: 1/32$^\circ$',color='k'); 

plt.ylabel('KE (Joules)')
plt.grid('on')
plt.xlim([0,35000])
#plt.ylim([0,5e17])

plt.title('GM Only, $C_{GM}=0.5$')

plt.subplot(2,1,2)
plt.plot(osGM1.Time,osGM1.APE.sum(axis=1),label='MEKE+GM 1/4$^\circ$',color='#233d4d'); 
plt.plot(osGM2.Time,osGM2.APE.sum(axis=1),label='MEKE+GM 1/2$^\circ$',color='#fe7f2d'); 
plt.plot(osGM3.Time,osGM3.APE.sum(axis=1),label='MEKE+GM 1$^\circ$',color='#fcca46'); 
plt.plot(osGM4.Time,osGM4.APE.sum(axis=1),label='MEKE+GM 2$^\circ$',color='#619b8a'); 
plt.plot(osGM3.Time,osGM3.Time*0+np.nanmean(oshr.APE.sum(axis=1)),label='Truth: 1/32$^\circ$',color='k'); 

plt.grid('on')
plt.xlim([0,35000])
plt.ylim([0,1.5e20])

plt.ylabel('APE (Joules)')
plt.xlabel('Time (days)')
plt.legend(loc='upper left',fontsize=8)

# %%
plt.figure(figsize=(7,7),dpi=200)



plt.subplot(2,1,1)

plt.plot(osBS1.Time,osBS1.KE.sum(axis=1),label='MEKE+BS 1/4$^\circ$',color='#233d4d');
plt.plot(osBS2.Time,osBS2.KE.sum(axis=1),label='MEKE+BS 1/2$^\circ$',color='#fe7f2d'); 
plt.plot(xr.concat([osBS3.Time[0:3000],osBS3.Time[-3400:]],dim='Time'),xr.concat([osBS3.KE[0:3000],osBS3.KE[-3400:]],dim='Time').sum(axis=1),label='MEKE+BS 1$^\circ$',color='#fcca46'); 
plt.plot(osBS4.Time[0:5890],osBS4.KE[0:5890].sum(axis=1),label='MEKE+BS 2$^\circ$',color='#619b8a'); 

plt.ylabel('KE (Joules)')
plt.grid('on')
plt.xlim([0,35000])
plt.ylim([0,10e17])

plt.title('BS Only, $C_{BS}=-0.2$')

plt.subplot(2,1,2)
plt.plot(osBS1.Time,osBS1.APE.sum(axis=1),label='MEKE+BS 1/4$^\circ$',color='#233d4d'); 
plt.plot(osBS2.Time,osBS2.APE.sum(axis=1),label='MEKE+BS 1/2$^\circ$',color='#fe7f2d'); 
plt.plot(xr.concat([osBS3.Time[0:3000],osBS3.Time[-3400:]],dim='Time'),xr.concat([osBS3.APE[0:3000],osBS3.APE[-3400:]],dim='Time').sum(axis=1),label='MEKE+BS 1$^\circ$',color='#fcca46'); 
plt.plot(osBS4.Time[0:5890],osBS4.APE[0:5890].sum(axis=1),label='MEKE+BS 2$^\circ$',color='#619b8a'); 
plt.plot(osGM3.Time,osGM3.Time*0+np.nanmean(oshr.APE.sum(axis=1)),label='Truth: 1/32$^\circ$',color='k'); 

plt.grid('on')
plt.xlim([0,35000])
plt.ylim([0,1.5e20])

plt.ylabel('APE (Joules)')
plt.xlabel('Time (days)')
plt.legend(fontsize=8)

# %%
plt.figure(figsize=(7,7),dpi=200)



plt.subplot(2,1,1)

plt.plot(osGMBS1.Time,osGMBS1.KE.sum(axis=1),label='MEKE+GM+BS 1/4$^\circ$',color='#233d4d'); 
plt.plot(osGMBS2.Time,osGMBS2.KE.sum(axis=1),label='MEKE+GM+BS 1/2$^\circ$',color='#fe7f2d'); 
plt.plot(osGMBS3.Time,osGMBS3.KE.sum(axis=1),label='MEKE+GM+BS 1$^\circ$',color='#fcca46'); 
plt.plot(osGMBS4.Time,osGMBS4.KE.sum(axis=1),label='MEKE+GM+BS 2$^\circ$',color='#619b8a'); 

plt.ylabel('KE (Joules)')
plt.grid('on')
plt.xlim([0,35000])
plt.ylim([0,8e17])

plt.title('GM+BS , $C_{GM}=0.15, C_{BS}=-0.15$')

plt.subplot(2,1,2)
plt.plot(osGMBS1.Time,osGMBS1.APE.sum(axis=1),label='MEKE+GM+BS 1/4$^\circ$',color='#233d4d'); 
plt.plot(osGMBS2.Time,osGMBS2.APE.sum(axis=1),label='MEKE+GM+BS 1/2$^\circ$',color='#fe7f2d'); 
plt.plot(osGMBS3.Time,osGMBS3.APE.sum(axis=1),label='MEKE+GM+BS 1$^\circ$',color='#fcca46'); 
plt.plot(osGMBS4.Time,osGMBS4.APE.sum(axis=1),label='MEKE+GM+BS 2$^\circ$',color='#619b8a'); 
plt.plot(osGM3.Time,osGM3.Time*0+np.nanmean(oshr.APE.sum(axis=1)),label='Truth: 1/32$^\circ$',color='k'); 

plt.grid('on')
plt.xlim([0,35000])
plt.ylim([0,1.5e20])

plt.ylabel('APE (Joules)')
plt.xlabel('Time (days)')
plt.legend(fontsize=8)

# %%
##Unparameterized run
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/default_noparameterization
fs = xr.open_dataset('static.nc', decode_times=False)
os = xr.open_dataset('ocean.stats.nc', decode_times=False)
area = fs.area_t

#Contains default setup based on Jansen et al 2019. MEKE_VISCOSITY_COEFF_KU = -0.15; MEKE_KHCOEFF = 0.15
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_GM_BS_default
fs0=xr.open_dataset('static.nc', decode_times=False)
os0=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE0 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH0 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU0 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src0 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src0=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))


# MEKE_VISCOSITY_COEFF_KU = -0.15; MEKE_KHCOEFF = 0.3
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test1
fs1=xr.open_dataset('static.nc', decode_times=False)
os1=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE1 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH1 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU1 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src1 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src1=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

## MEKE_VISCOSITY_COEFF_KU = -0.15; MEKE_KHCOEFF = 0.5
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test2
fs2=xr.open_dataset('static.nc', decode_times=False)
os2=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE2 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH2 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU2 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src2 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src2=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

# MEKE_VISCOSITY_COEFF_KU = -0.3; MEKE_KHCOEFF = 0.15
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test3
fs3=xr.open_dataset('static.nc', decode_times=False)
os3=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE3 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH3 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU3 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src3 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src3=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

# MEKE_VISCOSITY_COEFF_KU = -0.5; MEKE_KHCOEFF = 0.15
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test4
fs4=xr.open_dataset('static.nc', decode_times=False)
os4=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE4 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH4 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU4 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src4 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src4=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))


# MEKE_VISCOSITY_COEFF_KU = -0.3; MEKE_KHCOEFF = 0.3
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test5
fs5=xr.open_dataset('static.nc', decode_times=False)
os5=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE5 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH5 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU5 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src5 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src5=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

## MEKE_VISCOSITY_COEFF_KU = -0.5; MEKE_KHCOEFF = 0.5
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test6
fs6=xr.open_dataset('static.nc', decode_times=False)
os6=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE6 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH6 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU6 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src6 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src6=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))


## MEKE_VISCOSITY_COEFF_KU = -0.0; MEKE_KHCOEFF = 0.5
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test7
fs7=xr.open_dataset('static.nc', decode_times=False)
os7=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE7 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH7 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU7 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src7 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src7=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.0; MEKE_KHCOEFF = 0.6
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test8
fs8=xr.open_dataset('static.nc', decode_times=False)
os8=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE8 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH8 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU8 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src8 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src8=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

## MEKE_VISCOSITY_COEFF_KU = -0.0; MEKE_KHCOEFF = 0.8
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test9
fs9=xr.open_dataset('static.nc', decode_times=False)
os9=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE9 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH9 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU9 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src9 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src9=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))


## MEKE_VISCOSITY_COEFF_KU = -0.3; MEKE_KHCOEFF = 0.5
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test10
fs10=xr.open_dataset('static.nc', decode_times=False)
os10=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE10 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH10 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU10 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src10 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src10=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))


## MEKE_VISCOSITY_COEFF_KU = -0.5; MEKE_KHCOEFF = 0.3
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test11
fs11=xr.open_dataset('static.nc', decode_times=False)
os11=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE11 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH11 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU11= np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src11 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src11=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

## MEKE_VISCOSITY_COEFF_KU = -0.6; MEKE_KHCOEFF = 0.6
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test12
fs12=xr.open_dataset('static.nc', decode_times=False)
os12=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE12 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH12 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU12 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src12 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src12=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

## MEKE_VISCOSITY_COEFF_KU = -0.8; MEKE_KHCOEFF = 0.8
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test13
fs13=xr.open_dataset('static.nc', decode_times=False)
os13=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE13 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH13 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU13 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src13 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src13=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

## MEKE_VISCOSITY_COEFF_KU = -0.2; MEKE_KHCOEFF = 0.2
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test14
fs14=xr.open_dataset('static.nc', decode_times=False)
os14=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE14 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH14 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU14 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src14 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src14=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

## MEKE_VISCOSITY_COEFF_KU = -0.15; MEKE_KHCOEFF = 0.0
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test15
fs15=xr.open_dataset('static.nc', decode_times=False)
os15=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE15 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH15 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU15 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src15 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src15=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

## MEKE_VISCOSITY_COEFF_KU = -0.3; MEKE_KHCOEFF = 0.0
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test16
fs16=xr.open_dataset('static.nc', decode_times=False)
os16=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE16 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH16 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU16 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src16 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src16=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

## MEKE_VISCOSITY_COEFF_KU = -0.6; MEKE_KHCOEFF = 0.15
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test21
fs21=xr.open_dataset('static.nc', decode_times=False)
os21=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE21 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH21 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU21 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src21 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src21=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

## MEKE_VISCOSITY_COEFF_KU = -0; MEKE_KHCOEFF = 0.15
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test24
fs24=xr.open_dataset('static.nc', decode_times=False)
os24=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE24 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH24 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU24 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src24 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src24=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

## MEKE_VISCOSITY_COEFF_KU = -0; MEKE_KHCOEFF = 0.3
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test25
fs25=xr.open_dataset('static.nc', decode_times=False)
os25=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE25 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH25 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU25 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src25 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src25=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

## MEKE_VISCOSITY_COEFF_KU = -0.1; MEKE_KHCOEFF = 0
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test26
fs26=xr.open_dataset('static.nc', decode_times=False)
os26=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE26 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH26 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU26 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src26 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src26=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))

## MEKE_VISCOSITY_COEFF_KU = -0.2; MEKE_KHCOEFF = 0
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test27
fs27=xr.open_dataset('static.nc', decode_times=False)
os27=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKE27 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KH27 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KU27 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_src27 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_src27=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))


## GME TESTS:
## MEKE_VISCOSITY_COEFF_KU = -0; MEKE_KHCOEFF = 0.3 with advection and dissipation of MEKE
# %cd /glade/p/univ/unyu0004/eyankovsky/GME_testing/GME_test1
fsGME1=xr.open_dataset('static.nc', decode_times=False)
osGME1=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKEGME1 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KHGME1 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KUGME1 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_srcGME1 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_srcGME1=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))


## MEKE_VISCOSITY_COEFF_KU = -0; MEKE_KHCOEFF = 0.3 with advection and dissipation of MEKE, additional filtering (5 passes vs. 1 in test1&2)
# %cd /glade/p/univ/unyu0004/eyankovsky/GME_testing/GME_test3
fsGME3=xr.open_dataset('static.nc', decode_times=False)
osGME3=xr.open_dataset('ocean.stats.nc', decode_times=False)
MEKEGME3 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE'][-1,:]*area)/(np.nansum(area))
KHGME3 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KH'][-1,:]*area)/(np.nansum(area))
KUGME3 = np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_KU'][-1,:]*area)/(np.nansum(area))
GM_srcGME3 =np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_GM_src'][-1,:]*area)/(np.nansum(area))
MOM_srcGME3=np.nansum(xr.open_dataset('MEKEaverages_00031502.nc', decode_times=False)['MEKE_mom_src'][-1,:]*area)/(np.nansum(area))


#1/32 degree resolution, surface diagnostics are for uppermost 5 meters.
# %cd /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.03125deg_N15_baseline_hmix5
fshr = xr.open_dataset('static.nc', decode_times=False)
oshr = xr.open_mfdataset(['sub01/ocean.stats.nc','sub02/ocean.stats.nc','sub03/ocean.stats.nc','sub04/ocean.stats.nc',
                        'sub05/ocean.stats.nc','sub06/ocean.stats.nc','sub07/ocean.stats.nc','sub08/ocean.stats.nc',
                        'sub09/ocean.stats.nc','sub10/ocean.stats.nc','sub11/ocean.stats.nc','sub12/ocean.stats.nc',
                        'sub13/ocean.stats.nc','sub14/ocean.stats.nc','sub15/ocean.stats.nc','sub16/ocean.stats.nc',
                        'sub17/ocean.stats.nc','sub18/ocean.stats.nc','sub19/ocean.stats.nc','sub20/ocean.stats.nc'], decode_times=False)


# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/
# Out:
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/default_noparameterization
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_GM_BS_default
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test1
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test2
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test3
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test4
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test5
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test6
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test7
# /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test8
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test9
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test10
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test11
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test12
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test13
# ...

# %%
# plt.figure(figsize=(7,7),dpi=1200)

# #plt.subplot(3,1,1)    
# # plt.plot(os1.Time,os1.En); plt.plot(os2.Time,os2.En); plt.plot(os3.Time,os3.En); plt.plot(os4.Time,os4.En)
# # plt.plot(os5.Time,os5.En); plt.plot(os6.Time,os6.En); plt.plot(os7.Time,os7.En); plt.plot(os8.Time,os8.En); plt.plot(os9.Time+29500,os9.En)
# # plt.ylabel('total energy (Joules)') 

# plt.subplot(2,1,1)
# # plt.plot(os0.Time,os0.KE.sum(axis=1),label='$C_{GM}=0.15, C_{BS}=-0.15$ (DEFAULT)'); 
# # plt.plot(os15.Time,os15.KE.sum(axis=1),label='$C_{GM}=0.0, C_{BS}=-0.15$'); 
# # plt.plot(os24.Time,os24.KE.sum(axis=1),label='$C_{GM}=0.15, C_{BS}=-0.0$'); 

# plt.plot(os5.Time,os5.KE.sum(axis=1),label='$MEKE+GM+BS C_{GM}=0.30, C_{BS}=-0.30$'); 
# #plt.plot(os25.Time,os25.KE.sum(axis=1),label='$C_{GM}=0.30, C_{BS}=-0.0$'); 
# # plt.plot(os16.Time,os16.KE.sum(axis=1),label='$C_{GM}=0.0, C_{BS}=-0.30$'); 

# #plt.plot(oss1.Time,oss1.KE.sum(axis=1),label='Adv/Diss OFF $C_{GM}=0.30, C_{BS}=-0.30$'); 
# # plt.plot(oss2.Time,oss2.KE.sum(axis=1),label='Adv/Diss OFF $C_{GM}=0.30, C_{BS}=-0.0$'); 
# # plt.plot(oss4.Time,oss4.KE.sum(axis=1),label='Adv/Diss OFF $C_{GM}=0.80, C_{BS}=-0.80$'); 
# # plt.plot(oss5.Time,oss5.KE.sum(axis=1),label='Adv/Diss OFF $C_{GM}=0.15, C_{BS}=-0.15$'); 
# # plt.plot(oss6.Time,oss6.KE.sum(axis=1),label='Adv/Diss OFF $C_{GM}=0.15, C_{BS}=-0.0$'); 

# plt.plot(osGME1.Time,osGME1.KE.sum(axis=1),'-',label='MEKE+GME $C_{GM}=0.3$'); 
# #plt.plot(osGME2.Time,osGME2.KE.sum(axis=1),'-.',label='MEKE+GME no adv/diss $C_{GM}=0.3$'); 
# plt.plot(osGME3.Time,osGME3.KE.sum(axis=1),'-',label='MEKE+GME $C_{GM}=0.3$ additional filtering'); 


# plt.plot(oshr.Time+29500,oshr.KE.sum(axis=1),label='1/32$^\circ$ Reference case',color='k')
# plt.plot([0,35000],[2.27e18,2.27e18],'--k',label='1/32$^\circ$ coarsened to 1/2 degree')

# plt.ylabel('KE (Joules)')
# #plt.legend(fontsize=9)
# plt.grid('on')
# plt.xlim([0,35000])

# plt.subplot(2,1,2)
# # plt.plot(os0.Time,os0.APE.sum(axis=1),label='$C_{GM}=0.15, C_{BS}=-0.15$ (DEFAULT)'); 
# # plt.plot(os15.Time,os15.APE.sum(axis=1),label='$C_{GM}=0.0, C_{BS}=-0.15$'); 
# # plt.plot(os24.Time,os24.APE.sum(axis=1),label='$C_{GM}=0.15, C_{BS}=-0.0$'); 

# plt.plot(os5.Time,os5.APE.sum(axis=1),label='MEKE+GM+BS $C_{GM}=0.30, C_{BS}=-0.30$'); 
# # plt.plot(os25.Time,os25.APE.sum(axis=1),label='$C_{GM}=0.30, C_{BS}=-0.0$'); 
# # plt.plot(os16.Time,os16.APE.sum(axis=1),label='$C_{GM}=0.0, C_{BS}=-0.30$'); 

# #plt.plot(oss1.Time,oss1.APE.sum(axis=1),label='Adv/Diss OFF $C_{GM}=0.30, C_{BS}=-0.30$'); 
# # plt.plot(oss2.Time,oss2.APE.sum(axis=1),label='Adv/Diss OFF $C_{GM}=0.30, C_{BS}=-0.0$'); 
# # plt.plot(oss4.Time,oss4.APE.sum(axis=1),label='Adv/Diss OFF $C_{GM}=0.80, C_{BS}=-0.80$'); 
# # plt.plot(oss5.Time,oss5.APE.sum(axis=1),label='Adv/Diss OFF $C_{GM}=0.15, C_{BS}=-0.15$'); 
# # plt.plot(oss6.Time,oss6.APE.sum(axis=1),label='Adv/Diss OFF $C_{GM}=0.15, C_{BS}=-0.0$'); 

# plt.plot(osGME1.Time,osGME1.APE.sum(axis=1),'-',label='MEKE+GME $C_{GM}=0.3$'); 
# #plt.plot(osGME2.Time,osGME2.APE.sum(axis=1),'-.',label='MEKE+GME no adv/diss $C_{GM}=0.3$'); 
# plt.plot(osGME3.Time,osGME3.APE.sum(axis=1),'-',label='MEKE+GME $C_{GM}=0.3$ additional filtering'); 

# plt.plot(oshr.Time+29500,oshr.APE.sum(axis=1),label='1/32$^\circ$ Reference case',color='k')
# plt.plot([0,35000],[8.98e19,8.98e19],'--k',label='1/32$^\circ$ coarsened to 1/2 degree')

# plt.grid('on')
# plt.xlim([0,35000])
# plt.ylabel('APE (Joules)')
# plt.xlabel('Time (days)')
# plt.legend()


#plt.savefig('Energy_quarter_eighth_sixteenth_degree.png', dpi=200,bbox_inches='tight',pad_inches=0)
# DT is the time-step (in seconds) used to run the model
# The slight kink on the 1/8 degree run at 14500 days is because the time-step needed to be reduced because of high CFL with DT = 600 and needed a restart with DT = 450.

# %%
os.APE.sum(axis=1)[-100:].mean('Time')
# Out:
# <xarray.DataArray 'APE' ()>
# array(1.15911942e+20)

# %%
CBS = [0,-.15, -.15, -.15, -.30, -.50, -.30, -.50, 0., 0., 0., -.30, -.50, -.60, -.80, -.20, -0.15, -0.3, -0.6, 0, 0, -0.1, -0.2]
CGM = [0,.15, .30, .50, .15, .15, .30, .50, .50, .60, .80, .50, .30, .60, .80, .20, 0, 0, .15, .15, .3, 0, 0]

KE = [os.KE.sum(axis=1)[-100:].mean('Time'),   os0.KE.sum(axis=1)[-100:].mean('Time'),  os1.KE.sum(axis=1)[-100:].mean('Time'),  os2.KE.sum(axis=1)[-100:].mean('Time'),  os3.KE.sum(axis=1)[-100:].mean('Time'),  os4.KE.sum(axis=1)[-100:].mean('Time'),  os5.KE.sum(axis=1)[-100:].mean('Time'),
      os6.KE.sum(axis=1)[-100:].mean('Time'),  os7.KE.sum(axis=1)[-100:].mean('Time'),  os8.KE.sum(axis=1)[-100:].mean('Time'),  os9.KE.sum(axis=1)[-100:].mean('Time'),  os10.KE.sum(axis=1)[-100:].mean('Time'), os11.KE.sum(axis=1)[-100:].mean('Time'),
      os12.KE.sum(axis=1)[-100:].mean('Time'), os13.KE.sum(axis=1)[-100:].mean('Time'), os14.KE.sum(axis=1)[-100:].mean('Time'), os15.KE.sum(axis=1)[-100:].mean('Time'), os16.KE.sum(axis=1)[-100:].mean('Time'), os21.KE.sum(axis=1)[-100:].mean('Time'),
      os24.KE.sum(axis=1)[-100:].mean('Time'), os25.KE.sum(axis=1)[-100:].mean('Time'), os26.KE.sum(axis=1)[-100:].mean('Time'), os27.KE.sum(axis=1)[-100:].mean('Time')]/(np.array(2.27e+18))

APE = [os.APE.sum(axis=1)[-100:].mean('Time'),    os0.APE.sum(axis=1)[-100:].mean('Time'),  os1.APE.sum(axis=1)[-100:].mean('Time'),  os2.APE.sum(axis=1)[-100:].mean('Time'),  os3.APE.sum(axis=1)[-100:].mean('Time'),  os4.APE.sum(axis=1)[-100:].mean('Time'),  os5.APE.sum(axis=1)[-100:].mean('Time'),
       os6.APE.sum(axis=1)[-100:].mean('Time'),  os7.APE.sum(axis=1)[-100:].mean('Time'),  os8.APE.sum(axis=1)[-100:].mean('Time'),  os9.APE.sum(axis=1)[-100:].mean('Time'),  os10.APE.sum(axis=1)[-100:].mean('Time'), os11.APE.sum(axis=1)[-100:].mean('Time'),
       os12.APE.sum(axis=1)[-100:].mean('Time'), os13.APE.sum(axis=1)[-100:].mean('Time'), os14.APE.sum(axis=1)[-100:].mean('Time'), os15.APE.sum(axis=1)[-100:].mean('Time'), os16.APE.sum(axis=1)[-100:].mean('Time'), os21.APE.sum(axis=1)[-100:].mean('Time'),
       os24.APE.sum(axis=1)[-100:].mean('Time'), os25.APE.sum(axis=1)[-100:].mean('Time'), os26.APE.sum(axis=1)[-100:].mean('Time'), os27.APE.sum(axis=1)[-100:].mean('Time')]/(np.array(9.16e+19))
MEKE = [MEKE0, MEKE1, MEKE2, MEKE3, MEKE4, MEKE5, MEKE6, MEKE7, MEKE8, MEKE9, MEKE10, MEKE11, MEKE12, MEKE13, MEKE14, MEKE15, MEKE16, MEKE21, MEKE24, MEKE25, MEKE26, MEKE27]
KH = [KH0, KH1, KH2, KH3, KH4, KH5, KH6, KH7, KH8, KH9, KH10, KH11, KH12, KH13, KH14, KH15, KH16, KH21, KH24, KH25, KH26, KH27]
KU = [KU0, KU1, KU2, KU3, KU4, KU5, KU6, KU7, KU8, KU9, KU10, KU11, KU12, KU13, KU14, KU15, KU16, KU21, KU24, KU25, KU26, KU27]

MEKE_GM = [GM_src0, GM_src1, GM_src2, GM_src3, GM_src4, GM_src5, GM_src6, GM_src7, GM_src8, GM_src9, GM_src10, GM_src11, GM_src12, GM_src13, GM_src14, GM_src15, GM_src16, GM_src21, GM_src24, GM_src25, GM_src26, GM_src27]
MEKE_mom = [MOM_src0, MOM_src1, MOM_src2, MOM_src3, MOM_src4, MOM_src5, MOM_src6, MOM_src7, MOM_src8, MOM_src9, MOM_src10, MOM_src11, MOM_src12, MOM_src13, MOM_src14, MOM_src15, MOM_src16, MOM_src21, MOM_src24, MOM_src25, MOM_src26, MOM_src27]



CBS_failed  = [-0.5, -0.6, -0.8, -1., -0.8, -1.]
CGM_failed = [0,     0,    0,    0,    .15, .15]

# %%
val1 = [0.1, 0.15, 0.2, 0.3]
val2 = np.array([4.01, 4.22, 4.36, 5.23])/3.61

# %%
plt.figure(dpi=100)
plt.scatter(val1,val2)
plt.ylim([1,1.5])
plt.xticks([.1, .15, .2, .25, .3])
plt.xlabel("$C_{BS}$ coefficient",fontsize=12)
plt.ylabel("Global KE relative to unparametized case",fontsize=12)
plt.title("1/2 deg. NW2 with BS only")
# Out:
# Text(0.5, 1.0, '1/2 deg. NW2 with BS only')

# %%
np.nanmax(KE)
# Out:
# 2.353281277906485

# %%
fig = plt.figure(figsize=(8,6),dpi=200)
ax = fig.add_subplot(111)

plt.tricontourf(CBS,CGM,APE,cmap='Spectral_r',levels=np.linspace(0.3,1.5,13))
#plt.tricontourf(CBS,CGM,APE,cmap='RdBu_r',levels=np.linspace(0.3,1.7,15))


plt.xlim([-0.8,0]); plt.ylim([0,0.8])
plt.xlabel('$C_{BS}$',fontsize=14)
plt.ylabel('$C_{GM}$',fontsize=14)
#plt.title('1/2$^\circ$APE relative to unparameterized 1/2$^\circ$',fontsize=14)
plt.title('1/2$^\circ$APE relative to coarsened 1/32$^\circ$',fontsize=14)

ax.set_aspect('equal', 'box')

plt.colorbar(); plt.grid()
plt.scatter(CBS,CGM,s=20, c='k')
plt.scatter(CBS_failed,CGM_failed,s=20, c='w',edgecolor='k')

# %%
fig = plt.figure(figsize=(8,6),dpi=200)
ax = fig.add_subplot(111)

plt.tricontourf(CBS,CGM,KE,cmap='Spectral_r',levels=np.linspace(0.,.4,9))
#plt.tricontourf(CBS,CGM,KE,cmap='RdBu_r',levels=np.linspace(0.,2.4,25),norm=MidpointNormalize(midpoint=1.))


plt.xlim([-0.8,0]); plt.ylim([0,0.8])
plt.xlabel('$C_{BS}$',fontsize=14)
plt.ylabel('$C_{GM}$',fontsize=14)
plt.title('1/2$^\circ$ KE relative to coarsened 1/32$^\circ$',fontsize=14)
#plt.title('1/2$^\circ$ KE relative to unparameterized 1/2$^\circ$',fontsize=14)

ax.set_aspect('equal', 'box')


plt.colorbar(); plt.grid()
plt.scatter(CBS,CGM,s=20, c='k')
plt.scatter(CBS_failed,CGM_failed,s=20, c='w',edgecolor='k')

# %%
fig = plt.figure(figsize=(12,8),dpi=200)
ax = fig.add_subplot(111)

plt.scatter(CBS_failed,CGM_failed,s=100,color='w',edgecolors='k')

plt.scatter(CBS,CGM,s=500, c=APE,cmap='Spectral_r',edgecolors='k',alpha=0.7,vmin=0.5,vmax=1.5)

for i, label in enumerate(APE):
    plt.annotate(APE[i].round(2),(CBS[i]-0.028, CGM[i]-0.01),color='k',fontsize=10)


plt.xlim([-1.,.1]); plt.ylim([-0.05,1])
plt.xlabel('$C_{BS}$',fontsize=14)
plt.ylabel('$C_{GM}$',fontsize=14)
plt.title('APE relative to 1/32$^\circ$',fontsize=14)
ax.set_aspect('equal', 'box')
plt.colorbar(); plt.grid()

# %%
fig = plt.figure(figsize=(12,8),dpi=200)
ax = fig.add_subplot(111)

plt.scatter(CBS_failed,CGM_failed,s=100,color='w',edgecolors='k')

plt.scatter(CBS,CGM,s=500, c=KE,cmap='Spectral_r',edgecolors='k',alpha=0.7,vmin=0,vmax=.5)

for i, label in enumerate(KE):
    plt.annotate(KE[i].round(2),(CBS[i]-0.028, CGM[i]-0.01),color='k',fontsize=10)

    
plt.xlim([-1.,.1]); plt.ylim([-0.05,1])
plt.xlabel('$C_{BS}$',fontsize=14)
plt.ylabel('$C_{GM}$',fontsize=14)
plt.title('KE relative to 1/32$^\circ$',fontsize=14)
ax.set_aspect('equal', 'box')
plt.colorbar(); plt.grid()

# %%
fig = plt.figure(figsize=(12,8),dpi=200)
ax = fig.add_subplot(111)

plt.scatter(CBS_failed,CGM_failed,s=100,color='w',edgecolors='k')

plt.scatter(CBS,CGM,s=500, c=MEKE,cmap='Spectral_r',edgecolors='k',alpha=0.7,vmin=0,vmax=.01)
plt.scatter(CBS_simple+np.array(.05),CGM_simple, s=500, c=MEKE_simple, cmap='Spectral_r',edgecolors='k',alpha=0.7,marker='s',vmin=0,vmax=.01)

for i, label in enumerate(MEKE):
    plt.annotate(MEKE[i].round(4),(CBS[i]-0.028, CGM[i]-0.01),color='k',fontsize=6)
for i, label in enumerate(MEKE_simple):
    plt.annotate(MEKE_simple[i].round(4),(CBS_simple[i]+0.026, CGM_simple[i]-0.01),color='k',fontsize=6)


plt.xlim([-1.,.1]); plt.ylim([-0.05,1])
plt.xlabel('$C_{BS}$',fontsize=14)
plt.ylabel('$C_{GM}$',fontsize=14)
plt.title('Domain-averaged MEKE $[m^2/s^2]$',fontsize=14)
ax.set_aspect('equal', 'box')
plt.colorbar(); plt.grid()

# %%
fig = plt.figure(figsize=(12,8),dpi=200)
ax = fig.add_subplot(111)

plt.scatter(CBS_failed,CGM_failed,s=100,color='w',edgecolors='k')

plt.scatter(CBS,CGM,s=500, c=KH,cmap='Spectral_r',edgecolors='k',alpha=0.7,vmin=0.,vmax=10000)
plt.scatter(CBS_simple+np.array(.05),CGM_simple, s=500, c=KH_simple, cmap='Spectral_r',edgecolors='k',alpha=0.7,marker='s',vmin=0.,vmax=10000)

for i, label in enumerate(KH):
    plt.annotate(int(KH[i]),(CBS[i]-0.028, CGM[i]-0.01),color='k',fontsize=8)
for i, label in enumerate(KH_simple):
    plt.annotate(int(KH_simple[i]),(CBS_simple[i]+0.026, CGM_simple[i]-0.01),color='k',fontsize=7)


plt.xlim([-1.,.1]); plt.ylim([-0.05,1])
plt.xlabel('$C_{BS}$',fontsize=14)
plt.ylabel('$C_{GM}$',fontsize=14)
plt.title('Domain-averaged KH $[m^2/s]$',fontsize=14)
ax.set_aspect('equal', 'box')
plt.colorbar(); plt.grid()

# %%
fig = plt.figure(figsize=(12,8),dpi=200)
ax = fig.add_subplot(111)

plt.scatter(CBS_failed,CGM_failed,s=100,color='w',edgecolors='k')

plt.scatter(CBS,CGM,s=500, c=KU,cmap='Spectral',edgecolors='k',alpha=0.7,vmin=-10000,vmax=0)
plt.scatter(CBS_simple+np.array(.05),CGM_simple, s=500, c=KU_simple, cmap='Spectral',edgecolors='k',alpha=0.7,marker='s',vmin=-10000,vmax=0)

for i, label in enumerate(KU):
    plt.annotate(int(KU[i]),(CBS[i]-0.028, CGM[i]-0.01),color='k',fontsize=7)
for i, label in enumerate(KH_simple):
    plt.annotate(int(KU_simple[i]),(CBS_simple[i]+0.026, CGM_simple[i]-0.01),color='k',fontsize=6)


plt.xlim([-1.,.1]); plt.ylim([-0.05,1])/
plt.xlabel('$C_{BS}$',fontsize=14)
plt.ylabel('$C_{GM}$',fontsize=14)
plt.title('Domain-averaged KU $[m^2/s]$',fontsize=14)
ax.set_aspect('equal', 'box')
plt.colorbar(); plt.grid()

# %%
fig = plt.figure(figsize=(12,8),dpi=200)
ax = fig.add_subplot(111)

plt.scatter(CBS_failed,CGM_failed,s=100,color='w',edgecolors='k')

plt.scatter(CBS,CGM,s=500, c=MEKE_GM,cmap='Spectral',edgecolors='k',alpha=0.7,vmin=-0.005, vmax=0)
plt.scatter(CBS_simple+np.array(.05),CGM_simple, s=500, c=MEKE_GM_simple, cmap='Spectral',edgecolors='k',alpha=0.7,marker='s',vmin=-0.005, vmax=0)

for i, label in enumerate(MEKE_GM):
    plt.annotate(MEKE_GM[i].round(4),(CBS[i]-0.028, CGM[i]-0.01),color='k',fontsize=6)
for i, label in enumerate(MEKE_GM_simple):
    plt.annotate(MEKE_GM_simple[i].round(4),(CBS_simple[i]+0.026, CGM_simple[i]-0.01),color='k',fontsize=6)


plt.xlim([-1.,.1]); plt.ylim([-0.05,1])
plt.xlabel('$C_{BS}$',fontsize=14)
plt.ylabel('$C_{GM}$',fontsize=14)
plt.title('Domain-averaged MEKE_GM_src $[W/m^2]$',fontsize=14)
ax.set_aspect('equal', 'box')
plt.colorbar(); plt.grid()

# %%
fig = plt.figure(figsize=(12,8),dpi=200)
ax = fig.add_subplot(111)

plt.scatter(CBS_failed,CGM_failed,s=100,color='w',edgecolors='k')

plt.scatter(CBS,CGM,s=500, c=MEKE_mom,cmap='Spectral',edgecolors='k',alpha=0.7,vmin=-0.005, vmax=0.005)
plt.scatter(CBS_simple+np.array(.05),CGM_simple, s=500, c=MEKE_mom_simple, cmap='Spectral',edgecolors='k',alpha=0.7,marker='s',vmin=-0.005, vmax=0.005)

for i, label in enumerate(MEKE_mom):
    plt.annotate(MEKE_mom[i].round(3),(CBS[i]-0.028, CGM[i]-0.01),color='k',fontsize=7)
for i, label in enumerate(MEKE_mom_simple):
    plt.annotate(MEKE_mom_simple[i].round(3),(CBS_simple[i]+0.026, CGM_simple[i]-0.01),color='k',fontsize=7)


plt.xlim([-1.,.1]); plt.ylim([-0.05,1])
plt.xlabel('$C_{BS}$',fontsize=14)
plt.ylabel('$C_{GM}$',fontsize=14)
plt.title('Domain-averaged MEKE_mom_src $[W/m^2]$',fontsize=14)
ax.set_aspect('equal', 'box')
plt.colorbar(); plt.grid()
