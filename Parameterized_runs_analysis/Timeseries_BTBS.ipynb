# %%
from netCDF4 import Dataset
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import xarray as xr
from xgcm import Grid
import numpy as np
import cmocean
import warnings
warnings.filterwarnings("ignore")

# %%
##Unparameterized run
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/default_noparameterization
fs = xr.open_dataset('static.nc', decode_times=False)
os = xr.open_dataset('ocean.stats.nc', decode_times=False)

#Contains default setup based on Jansen et al 2019. MEKE_VISCOSITY_COEFF_KU = -0.15; MEKE_KHCOEFF = 0.15
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_default
fs0=xr.open_dataset('static.nc', decode_times=False)
os0=xr.open_dataset('ocean.stats.nc', decode_times=False)

# MEKE_VISCOSITY_COEFF_KU = -0.15; MEKE_KHCOEFF = 0.3
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test1
fs1=xr.open_dataset('static.nc', decode_times=False)
os1=xr.open_dataset('ocean.stats.nc', decode_times=False)

## MEKE_VISCOSITY_COEFF_KU = -0.15; MEKE_KHCOEFF = 0.5
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test2
fs2=xr.open_dataset('static.nc', decode_times=False)
os2=xr.open_dataset('ocean.stats.nc', decode_times=False)

# MEKE_VISCOSITY_COEFF_KU = -0.3; MEKE_KHCOEFF = 0.15
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test3
fs3=xr.open_dataset('static.nc', decode_times=False)
os3=xr.open_dataset('ocean.stats.nc', decode_times=False)

# MEKE_VISCOSITY_COEFF_KU = -0.5; MEKE_KHCOEFF = 0.15
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test4
fs4=xr.open_dataset('static.nc', decode_times=False)
os4=xr.open_dataset('ocean.stats.nc', decode_times=False)


# MEKE_VISCOSITY_COEFF_KU = -0.3; MEKE_KHCOEFF = 0.3
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test5
fs5=xr.open_dataset('static.nc', decode_times=False)
os5=xr.open_dataset('ocean.stats.nc', decode_times=False)

## MEKE_VISCOSITY_COEFF_KU = -0.5; MEKE_KHCOEFF = 0.5
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test6
fs6=xr.open_dataset('static.nc', decode_times=False)
os6=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.0; MEKE_KHCOEFF = 0.5
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test7
fs7=xr.open_dataset('static.nc', decode_times=False)
os7=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.0; MEKE_KHCOEFF = 0.6
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test8
fs8=xr.open_dataset('static.nc', decode_times=False)
os8=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.0; MEKE_KHCOEFF = 0.8
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test9
fs9=xr.open_dataset('static.nc', decode_times=False)
os9=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.3; MEKE_KHCOEFF = 0.5
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test10
fs10=xr.open_dataset('static.nc', decode_times=False)
os10=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.5; MEKE_KHCOEFF = 0.3
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test11
fs11=xr.open_dataset('static.nc', decode_times=False)
os11=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.6; MEKE_KHCOEFF = 0.6
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test12
fs12=xr.open_dataset('static.nc', decode_times=False)
os12=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.8; MEKE_KHCOEFF = 0.8
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test13
fs13=xr.open_dataset('static.nc', decode_times=False)
os13=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.2; MEKE_KHCOEFF = 0.2
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test14
fs14=xr.open_dataset('static.nc', decode_times=False)
os14=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

# ## MEKE_VISCOSITY_COEFF_KU = -0.15; MEKE_KHCOEFF = 0.0
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test15
# fs15=xr.open_dataset('static.nc', decode_times=False)
# os15=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.3; MEKE_KHCOEFF = 0.0
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test16
fs16=xr.open_dataset('static.nc', decode_times=False)
os16=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.6; MEKE_KHCOEFF = 0.0
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test18
fs18=xr.open_dataset('static.nc', decode_times=False)
os18=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.6; MEKE_KHCOEFF = 0.15
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test21
fs21=xr.open_dataset('static.nc', decode_times=False)
os21=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.8; MEKE_KHCOEFF = 0.15
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test22
fs22=xr.open_dataset('static.nc', decode_times=False)
os22=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -1.; MEKE_KHCOEFF = 0.15
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test23
fs23=xr.open_dataset('static.nc', decode_times=False)
os23=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0; MEKE_KHCOEFF = 0.15
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test24
fs24=xr.open_dataset('static.nc', decode_times=False)
os24=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0; MEKE_KHCOEFF = 0.3
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test25
fs25=xr.open_dataset('static.nc', decode_times=False)
os25=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.1; MEKE_KHCOEFF = 0
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test26
fs26=xr.open_dataset('static.nc', decode_times=False)
os26=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

## MEKE_VISCOSITY_COEFF_KU = -0.2; MEKE_KHCOEFF = 0
# %cd /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test27
fs27=xr.open_dataset('static.nc', decode_times=False)
os27=xr.open_dataset('ocean.stats.nc', decode_times=False)
# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/

#1/32 degree resolution, surface diagnostics are for uppermost 5 meters.
# %cd /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.03125deg_N15_baseline_hmix5
fshr = xr.open_dataset('static.nc', decode_times=False)
oshr = xr.open_mfdataset(['sub01/ocean.stats.nc','sub02/ocean.stats.nc','sub03/ocean.stats.nc','sub04/ocean.stats.nc',
                        'sub05/ocean.stats.nc','sub06/ocean.stats.nc','sub07/ocean.stats.nc','sub08/ocean.stats.nc',
                        'sub09/ocean.stats.nc','sub10/ocean.stats.nc','sub11/ocean.stats.nc','sub12/ocean.stats.nc',
                        'sub13/ocean.stats.nc','sub14/ocean.stats.nc','sub15/ocean.stats.nc','sub16/ocean.stats.nc',
                        'sub17/ocean.stats.nc','sub18/ocean.stats.nc','sub19/ocean.stats.nc','sub20/ocean.stats.nc'], decode_times=False)


# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/
# Out:
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/default_noparameterization
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_default
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test1
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test2
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test3
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test4
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test5
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test6
# /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test7
# /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test8
# /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/MEKE_test9
# /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis
# /glade/p/univ/unyu0004/eyankovsky/MEKE_testing/BTBS_test10
# ...

# %%
print(os2.En)
# Out:
# <xarray.DataArray 'En' (Time: 6403)>
# array([1.701845e+08, 1.748984e+16, 2.706303e+16, ..., 8.430660e+19,
#        8.430785e+19, 8.430940e+19])
# Coordinates:
#   * Time     (Time) float64 0.0 5.0 10.0 15.0 ... 3.199e+04 3.2e+04 3.2e+04
# Attributes:
#     long_name:  Total Energy
#     units:      Joules

# %%
plt.figure(figsize=(10,15),dpi=100)

#plt.subplot(3,1,1)    
# plt.plot(os1.Time,os1.En); plt.plot(os2.Time,os2.En); plt.plot(os3.Time,os3.En); plt.plot(os4.Time,os4.En)
# plt.plot(os5.Time,os5.En); plt.plot(os6.Time,os6.En); plt.plot(os7.Time,os7.En); plt.plot(os8.Time,os8.En); plt.plot(os9.Time+29500,os9.En)
# plt.ylabel('total energy (Joules)') 

plt.subplot(2,1,1)
# plt.plot(os0.Time,os0.KE.sum(axis=1),label='$C_{GM}=0.15, C_{BS}=-0.15$ (DEFAULT)'); 
# plt.plot(os1.Time,os1.KE.sum(axis=1),label='$C_{GM}=0.30, C_{BS}=-0.15$'), 
# plt.plot(os2.Time,os2.KE.sum(axis=1),label='$C_{GM}=0.50, C_{BS}=-0.15$'); 
# plt.plot(os3.Time,os3.KE.sum(axis=1),label='$C_{GM}=0.15, C_{BS}=-0.30$'); 
# plt.plot(os4.Time,os4.KE.sum(axis=1),label='$C_{GM}=0.15, C_{BS}=-0.50$'); 
# plt.plot(os5.Time,os5.KE.sum(axis=1),label='$C_{GM}=0.30, C_{BS}=-0.30$'); 
# plt.plot(os6.Time,os6.KE.sum(axis=1),label='$C_{GM}=0.50, C_{BS}=-0.50$'); 
plt.plot(os7.Time,os7.KE.sum(axis=1),label='$C_{GM}=0.50, C_{BS}=-0.00$'); 
plt.plot(os8.Time,os8.KE.sum(axis=1),label='$C_{GM}=0.60, C_{BS}=-0.00$'); 
plt.plot(os9.Time,os9.KE.sum(axis=1),label='$C_{GM}=0.80, C_{BS}=-0.00$'); 
# plt.plot(os10.Time,os10.KE.sum(axis=1),label='$C_{GM}=0.50, C_{BS}=-0.30$'); 
# plt.plot(os11.Time,os11.KE.sum(axis=1),label='$C_{GM}=0.30, C_{BS}=-0.50$'); 
# plt.plot(os12.Time,os12.KE.sum(axis=1),label='$C_{GM}=0.60, C_{BS}=-0.60$'); 
# plt.plot(os13.Time,os13.KE.sum(axis=1),label='$C_{GM}=0.80, C_{BS}=-0.80$'); 
# plt.plot(os14.Time,os14.KE.sum(axis=1),label='$C_{GM}=0.20, C_{BS}=-0.20$'); 
plt.plot(oshr.Time+29500,oshr.KE.sum(axis=1),label='1/32$^\circ$ Reference case')
plt.ylabel('KE (Joules)')
plt.legend(fontsize=12)
plt.grid('on')
plt.xlim([0,35000])

plt.subplot(2,1,2)
# plt.plot(os0.Time,os0.APE.sum(axis=1),label='$C_{GM}=0.15, C_{BS}=-0.15$ (DEFAULT)'); 
# plt.plot(os1.Time,os1.APE.sum(axis=1),label='$C_{GM}=0.30, C_{BS}=-0.15$'), 
# plt.plot(os2.Time,os2.APE.sum(axis=1),label='$C_{GM}=0.50, C_{BS}=-0.15$'); 
# plt.plot(os3.Time,os3.APE.sum(axis=1),label='$C_{GM}=0.15, C_{BS}=-0.30$'); 
# plt.plot(os4.Time,os4.APE.sum(axis=1),label='$C_{GM}=0.15, C_{BS}=-0.50$'); 
# plt.plot(os5.Time,os5.APE.sum(axis=1),label='$C_{GM}=0.30, C_{BS}=-0.30$'); 
# plt.plot(os6.Time,os6.APE.sum(axis=1),label='$C_{GM}=0.50, C_{BS}=-0.50$'); 
plt.plot(os7.Time,os7.APE.sum(axis=1),label='$C_{GM}=0.50, C_{BS}=-0.00$'); 
plt.plot(os8.Time,os8.APE.sum(axis=1),label='$C_{GM}=0.60, C_{BS}=-0.00$'); 
plt.plot(os9.Time,os9.APE.sum(axis=1),label='$C_{GM}=0.80, C_{BS}=-0.00$'); 
# plt.plot(os10.Time,os10.APE.sum(axis=1),label='$C_{GM}=0.50, C_{BS}=-0.30$'); 
# plt.plot(os11.Time,os11.APE.sum(axis=1),label='$C_{GM}=0.30, C_{BS}=-0.50$'); 
# plt.plot(os12.Time,os12.APE.sum(axis=1),label='$C_{GM}=0.60, C_{BS}=-0.60$'); 
# plt.plot(os13.Time,os13.APE.sum(axis=1),label='$C_{GM}=0.80, C_{BS}=-0.80$'); 
#plt.plot(os14.Time,os14.APE.sum(axis=1),label='$C_{GM}=0.20, C_{BS}=-0.20$'); 
plt.plot(oshr.Time+29500,oshr.APE.sum(axis=1),label='1/32$^\circ$ Reference case')
#plt.legend(fontsize=12)
plt.grid('on')
plt.xlim([0,35000])
plt.ylabel('APE (Joules)')
plt.xlabel('Time (days)')



#plt.savefig('Energy_quarter_eighth_sixteenth_degree.png', dpi=200,bbox_inches='tight',pad_inches=0)
# DT is the time-step (in seconds) used to run the model
# The slight kink on the 1/8 degree run at 14500 days is because the time-step needed to be reduced because of high CFL with DT = 600 and needed a restart with DT = 450.
# Out:
# Text(0.5, 0, 'Time (days)')

# %%
CBS = [-.15, -.15, -.15, -.30, -.50, -.30, -.50,  0,  0,  0, -.30, -.50, -.60, -.80, -.20, -.30, -.60, -.60, -.80,  -1,   0,   0, -.1, -.2]
CGM = [0.15, 0.30, 0.50, 0.15, 0.15, 0.30, 0.50, .5, .6, .8, 0.50, 0.30, 0.60, 0.80, 0.20,    0,    0, 0.15, 0.15, .15, .15, .30,   0,   0]

CBS_failed  =[-.15, -.5, -.8, -1,]
CGM_failed = [0,      0,   0,  0,]

KE = [os0.KE.sum(axis=1)[-100:].mean('Time'),  os1.KE.sum(axis=1)[-100:].mean('Time'),  os2.KE.sum(axis=1)[-100:].mean('Time'),  os3.KE.sum(axis=1)[-100:].mean('Time'),  os4.KE.sum(axis=1)[-100:].mean('Time'),  os5.KE.sum(axis=1)[-100:].mean('Time'),
      os6.KE.sum(axis=1)[-100:].mean('Time'),  os7.KE.sum(axis=1)[-100:].mean('Time'),  os8.KE.sum(axis=1)[-100:].mean('Time'),  os9.KE.sum(axis=1)[-100:].mean('Time'),  os10.KE.sum(axis=1)[-100:].mean('Time'), os11.KE.sum(axis=1)[-100:].mean('Time'),
      os12.KE.sum(axis=1)[-100:].mean('Time'), os13.KE.sum(axis=1)[-100:].mean('Time'), os14.KE.sum(axis=1)[-100:].mean('Time'), os16.KE.sum(axis=1)[-100:].mean('Time'), os18.KE.sum(axis=1)[-100:].mean('Time'),
      os21.KE.sum(axis=1)[-100:].mean('Time'), os22.KE.sum(axis=1)[-100:].mean('Time'), os23.KE.sum(axis=1)[-100:].mean('Time'), os24.KE.sum(axis=1)[-100:].mean('Time'), os25.KE.sum(axis=1)[-100:].mean('Time'),
      os26.KE.sum(axis=1)[-100:].mean('Time'), os27.KE.sum(axis=1)[-100:].mean('Time')]/(np.array(2.27e18))

APE = [os0.APE.sum(axis=1)[-100:].mean('Time'),  os1.APE.sum(axis=1)[-100:].mean('Time'),  os2.APE.sum(axis=1)[-100:].mean('Time'),  os3.APE.sum(axis=1)[-100:].mean('Time'),  os4.APE.sum(axis=1)[-100:].mean('Time'),  os5.APE.sum(axis=1)[-100:].mean('Time'),
      os6.APE.sum(axis=1)[-100:].mean('Time'),  os7.APE.sum(axis=1)[-100:].mean('Time'),  os8.APE.sum(axis=1)[-100:].mean('Time'),  os9.APE.sum(axis=1)[-100:].mean('Time'),  os10.APE.sum(axis=1)[-100:].mean('Time'), os11.APE.sum(axis=1)[-100:].mean('Time'),
      os12.APE.sum(axis=1)[-100:].mean('Time'), os13.APE.sum(axis=1)[-100:].mean('Time'), os14.APE.sum(axis=1)[-100:].mean('Time'), os16.APE.sum(axis=1)[-100:].mean('Time'), os18.APE.sum(axis=1)[-100:].mean('Time'),
      os21.APE.sum(axis=1)[-100:].mean('Time'), os22.APE.sum(axis=1)[-100:].mean('Time'), os23.APE.sum(axis=1)[-100:].mean('Time'), os24.APE.sum(axis=1)[-100:].mean('Time'), os25.APE.sum(axis=1)[-100:].mean('Time'),
      os26.APE.sum(axis=1)[-100:].mean('Time'), os27.APE.sum(axis=1)[-100:].mean('Time')]/(np.array(8.98e19))

# %%
APE
# Out:
# array([1.20350739, 1.04480659, 0.93680976, 0.87702193, 0.67889077,
#        0.78769652, 0.54141443, 1.03314612, 0.93030781, 0.77118362,
#        0.72033625, 0.59217826, 0.49509324, 0.42643742, 1.03078355,
#        0.97457685, 0.64977506, 0.63135764, 0.56178838, 0.51564127,
#        1.40751155, 1.28005024, 1.24183431, 1.11959731])

# %%
val1 = [0.1, 0.15, 0.2, 0.3]
val2 = [0.1, 0.2, 0.3, .6]
val3 = np.array([4.01, 4.22, 4.36, 5.23])/3.61
val4 = np.array([3.88, 4.1, 4.95, 8.11])/3.61

plt.figure(dpi=100)
plt.scatter(val1,val3,label='BS')
plt.scatter(val2,val4,label='BT BS')
plt.ylim([1,1.5]);plt.xlim([0.05,0.35])
plt.xticks([.1, .15, .2, .25, .3])
plt.xlabel("$C_{BS}$ coefficient",fontsize=12)
plt.ylabel("Global KE relative to unparametized case",fontsize=12)
plt.title("1/2 deg. NW2 with BS only")
plt.legend()

# %%
fig = plt.figure(figsize=(12,8),dpi=200)
ax = fig.add_subplot(111)

plt.scatter(CBS_failed,CGM_failed,s=100,color='w',edgecolors='k')

plt.scatter(CBS,CGM,s=500, c=APE,cmap='Spectral_r',edgecolors='k',alpha=0.7,vmax=1.4)
for i, label in enumerate(APE):
    plt.annotate(APE[i].round(2),(CBS[i]-0.028, CGM[i]-0.01),color='k',fontsize=10)

plt.xlim([-1.05,.1]); plt.ylim([-0.05,1])
plt.xlabel('$C_{BS}$',fontsize=14)
plt.ylabel('$C_{GM}$',fontsize=14)
plt.title('APE relative to 1/32$^\circ$',fontsize=14)
ax.set_aspect('equal', 'box')
plt.colorbar(); plt.grid()

# %%
fig = plt.figure(figsize=(12,8),dpi=200)
ax = fig.add_subplot(111)

plt.scatter(CBS_failed,CGM_failed,s=100,color='w',edgecolors='k')

plt.scatter(CBS,CGM,s=500, c=KE,cmap='Spectral_r',edgecolors='k',alpha=0.7,vmax=0.35)
for i, label in enumerate(KE):
    plt.annotate(KE[i].round(2),(CBS[i]-0.028, CGM[i]-0.01),color='k',fontsize=10)

plt.xlim([-1.05,.1]); plt.ylim([-0.05,1])
plt.xlabel('$C_{BS}$',fontsize=14)
plt.ylabel('$C_{GM}$',fontsize=14)
plt.title('KE relative to 1/32$^\circ$',fontsize=14)
ax.set_aspect('equal', 'box')
plt.colorbar(); plt.grid()
